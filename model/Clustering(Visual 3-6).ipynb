# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
std_mrg_kmeans=pd.read_csv(r'C:\Users\m_joekid\Desktop\Startup Success\std_mrg_kmeans.csv')

# %% [markdown]
# ## POST Kmeans Clustering (-1FE||NO-PCA||K=8) Visualisations

# %%
plt.figure(figsize=(12,12))
sns.boxplot(x='Segment Kmeans',y='raised_amount_usd',data=std_mrg_kmeans)
plt.title('Segmentation K-means')
# Out:
# Text(0.5, 1.0, 'Segmentation K-means')

# %%
plt.figure(figsize=(12,12))
sns.boxplot(x='Segment Kmeans',y='raised_amount_usd',hue='is_first_round',data=std_mrg_kmeans)
plt.title('Segmentation K-means')
# Out:
# Text(0.5, 1.0, 'Segmentation K-means')

# %%
plt.figure(figsize=(12,12))
sns.boxplot(x='Segment Kmeans',y='raised_amount_usd',hue='is_last_round',data=std_mrg_kmeans)
plt.title('Segmentation K-means')
# Out:
# Text(0.5, 1.0, 'Segmentation K-means')

# %%
# THIS PLOT NEEDS TO BE MAXIMIZED
plt.figure(figsize=(60,60))
sns.boxplot(hue='Segment Kmeans',y='raised_amount_usd',x='funding_round_type',data=std_mrg_kmeans)
plt.title('Segmentation K-means')
# Out:
# Text(0.5, 1.0, 'Segmentation K-means')
